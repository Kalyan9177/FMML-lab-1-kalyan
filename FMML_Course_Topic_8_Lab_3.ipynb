# %% [markdown]
# <a href="https://colab.research.google.com/github/Kalyan9177/FMML_LAB_ASSIGNMENTS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-04 05:13:59--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   124MB/s    in 0.6s
#
# 2023-05-04 05:14:00 (124 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 4337    1410.6264v1  In recent scene recognition research images or...    cs
# 36714   1312.4640v1  Lately, there has been an increasing interest ...    cs
# 569     1411.4116v1  This paper aims to explore the effect of prior...    cs
# 2450    1403.1893v1  It is widely known in the machine learning com...  stat
# 22248  1510.04378v1  In order to identify important variables that ...  stat
# ...             ...                                                ...   ...
# 18611   1106.1816v1  Recent years are seeing an increasing need for...    cs
# 5939    1305.1956v2  Modern machine learning methods are critical t...  stat
# 11761  1611.06265v2  Deep clustering is the first method to handle ...  stat
# 16938  1707.05468v1  The article describes a model of automatic ana...    cs
# 13096  1511.04514v1  We study parameter estimation and asymptotic i...  stat
#
#                                                    title  year  \
# 4337   Capturing spatial interdependence in image fea...  2014
# 36714  A Review of Temporal Aspects of Hand Gesture A...  2013
# 569    Investigating the Role of Prior Disambiguation...  2014
# 2450   Becoming More Robust to Label Noise with Class...  2014
# 22248  Robust Learning for Optimal Treatment Decision...  2015
# ...                                                  ...   ...
# 18611  Monitoring Teams by Overhearing: A Multi-Agent...  2011
# 5939   Joint Topic Modeling and Factor Analysis of Te...  2013
# 11761  Deep Clustering and Conventional Networks for ...  2016
# 16938  Detecting Intentional Lexical Ambiguity in Eng...  2017
# 13096  Sparse Nonlinear Regression: Parameter Estimat...  2015
#
#                                                 keywords
# 4337   [recognition, represented, disorganized, origi...
# 36714  [increasing, recognition, techniques, developm...
# 569    [disambiguation, compositional, representation...
# 2450   [community, detrimental, approaches, measureme...
# 22248  [important, variables, treatment, penalized, r...
# ...                                                  ...
# 18611  [increasing, monitoring, cooperating, visualiz...
# 5939   [development, personalized, individual, develo...
# 11761  [clustering, separation, scenarios, arbitrary,...
# 16938  [describes, automatic, intentionally, thesauru...
# 13096  [parameter, estimation, asymptotic, inference,...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 4337     [recognition, represented, disorganized, origi...
# 36714    [increasing, recognition, techniques, developm...
# 569      [disambiguation, compositional, representation...
# 2450     [community, detrimental, approaches, measureme...
# 22248    [important, variables, treatment, penalized, r...
#                                ...
# 37275    [effective, difficulty, providing, guarantees,...
# 37399    [publishing, comprehensive, methodology, suppo...
# 5488     [dimension, reduction, supervised, dimension, ...
# 16234    [described, paragraph, distributed, representa...
# 22039    [significantly, performance, situations, regre...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8827 words.
# Out of those 4639 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ff203bee-3358-49f7-bdbe-98392478c84e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff203bee-3358-49f7-bdbe-98392478c84e")) {                    Plotly.newPlot(                        "ff203bee-3358-49f7-bdbe-98392478c84e",                        [{"x":["combinations","representative","variation","demonstrate","considerably","constrained","interdependence","developed","capturing","estimates","represented","properties","recognition","appropriate","originally","resulting","experimentally","procedure","representation","accurately","generative","traditional","different","distribution","multimodal","highlighting","techniques","information","according","applications","interaction","referring","recognize","increasing","interfaces","systematic","literature","sequences","movements","development","characterized","psycholinguistic","discourse","conversation","organized","laborious","methodology","understand","compositional","disambiguation","compounds","evaluations","investigating","representations","disambiguate","effective","classification","considered","classifiers","measurement","increases","integrating","diversity","community","predictions","significantly","weighting","classifier","filtering","selecting","detrimental","technique","determine","identification","instances","algorithms","approaches","depression","misspecification","consistency","variables","predictors","application","propensity","penalized","treatment","asymptotic","regressions","investigated","conditional","selection","important","simulations","estimation","estimators","regression","dimension","dimensional","empirical","misspecified","polynomial","distributions","evaluated","estimated","dimensionality","framework","performance","component","significant","projections","frequently","projected","projection","extensive","outperforms","typically","principal","predictive","proposing","statistically","alternative","prediction","heuristic","particular","components","assumptions","widespread","straightforward","reduction","successful","competitive","experiments","minimizes","difference","supervised","examination","implement","strategies","baselines","describes","evaluation","embeddings","computation","candidate","embedding","similarity","performed","sentences","construct","isomorphic","possesses","representable","regularized","admissible","reproducing","targeting","functions","isometrically","continuous","construction","functionals","representer","integrable","correspond","interacting","postulated","explanatory","learnable","disentangle","disentangling","disentangles","experiment","variations","postulate","statistical","objective","controllable","discovered","potentially","independently","underlying","hypothesize","extrinsic","environment","specifically","fundamental","direction","relations","univariate","synthetic","observational","functional","efficient","practical","inferring","description","especially","algorithm","complexity","principle"],"y":[33,33,68,551,28,77,5,213,42,62,99,221,381,90,13,163,51,130,383,60,137,192,751,205,34,9,400,720,86,421,73,10,50,119,23,41,136,115,14,125,29,3,16,22,15,5,60,72,19,14,1,52,12,242,3,238,484,144,91,25,47,35,47,90,76,283,18,130,62,36,4,241,66,106,83,585,415,0,2,65,138,10,231,0,4,27,22,3,44,104,152,374,40,197,9,99,66,157,162,1,53,129,141,70,56,550,853,99,259,19,22,20,44,168,274,106,33,55,17,19,57,212,54,253,101,58,14,24,104,77,130,605,23,64,195,10,70,93,63,84,218,67,157,48,99,136,125,69,80,3,10,1,52,8,7,8,236,0,117,68,4,1,1,32,16,1,3,16,10,5,0,87,70,4,145,149,8,24,52,43,136,5,4,113,179,83,58,95,3,134,8,39,373,141,20,76,124,760,239,63],"type":"bar"},{"x":["combinations","representative","variation","demonstrate","considerably","constrained","inter ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4639,), (4639, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.83

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Sequence</span> <span style=''>to</span> <span style=''>Label</span> <span style=''>Script</span> <span style='background-color:rgba(0, 255, 0, 0.3006134969325153);'>Identification</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.6842105263157895);'>Multilingual</span> <span style=''>OCR</span> <br/><br/><span style=''>We</span> <span style=''>describe</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>line</span> <span style=''>level</span> <span style=''>script</span> <span style='background-color:rgba(0, 255, 0, 0.3006134969325153);'>identification</span> <span style=''>method</span> <span style=''>Previous</span> <span style=''>work</span> <span style=''>repurposed</span> <span style=''>an</span> <span style=''>OCR</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333326);'>generating</span> <span style=''>per</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857143);'>character</span> <span style=''>script</span> <span style=''>codes</span> <span style=''>counted</span> <span style=''>to</span> <span style=''>obtain</span> <span style=''>line</span> <span style=''>level</span> <span style=''>script</span> <span style='background-color:rgba(0, 255, 0, 0.3006134969325153);'>identification</span> <span style=''>This</span> <span style=''>has</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>shortcomings</span> <span style=''>First</span> <span style=''>as</span> <span style=''>a</span> <span style=''>sequence</span> <span style=''>to</span> <span style=''>sequence</span> <span style=''>model</span> <span style=''>it</span> <span style=''>is</span> <span style=''>more</span> <span style=''>complex</span> <span style=''>than</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>necessary</span> <span style=''>for</span> <span style=''>the</span> <span style=''>sequence</span> <span style=''>to</span> <span style=''>label</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>line</span> <span style=''>script</span> <span style='background-color:rgba(0, 255, 0, 0.3006134969325153);'>identification</span> <span style=''>This</span> <span style=''>makes</span> <span style=''>it</span> <span style=''>harder</span> <span style=''>to</span> <span style=''>train</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inefficient</span> <span style=''>to</span> <span style=''>run</span> <span style=''>Second</span> <span style=''>the</span> <span style=''>counting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>heuristic</span> <span style=''>may</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>suboptimal</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>a</span> <span style=''>learned</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Therefore</span> <span style=''>we</span> <span style=''>reframe</span> <span style=''>line</span> <span style=''>script</span> <span style='background-color:rgba(0, 255, 0, 0.3006134969325153);'>identification</span> <span style=''>as</span> <span style=''>a</span> <span style=''>sequence</span> <span style=''>to</span> <span style=''>label</span> <span style=''>problem</span> <span style=''>and</span> <span style=''>solve</span> <span style=''>it</span> <span style=''>using</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style=''>trained</span> <span style=''>end</span> <span style=''>toend</span> <span style=''>Encoder</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Summarizer</span> <span style=''>The</span> <span style=''>encoder</span> <span style=''>converts</span> <span style=''>a</span> <span style=''>line</span> <span style=''>image</span> <span style=''>into</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Structured</span> <span style=''>Variable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Selection</span> <span style=''>with</span> <span style=''>Sparsity</span> <span style=''>Inducing</span> <span style=''>Norms</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style=''>risk</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimization</span> <span style=''>problem</span> <span style=''>for</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style=''>sparsity</span> <span style=''>inducing</span> <span style=''>norms</span> <span style=''>These</span> <span style=''>are</span> <span style=''>defined</span> <span style=''>as</span> <span style=''>sums</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Euclidean</span> <span style=''>norms</span> <span style=''>on</span> <span style=''>certain</span> <span style=''>subsets</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extending</span> <span style=''>the</span> <span style=''>usual</span> <span style=''>ell</span> <span style=''>1</span> <span style=''>norm</span> <span style=''>and</span> <span style=''>the</span> <span style=''>group</span> <span style=''>ell</span> <span style=''>1</span> <span style=''>norm</span> <span style=''>by</span> <span style=''>allowing</span> <span style=''>the</span> <span style=''>subsets</span> <span style=''>to</span> <span style=''>overlap</span> <span style=''>This</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>a</span> <span style=''>specific</span> <span style=''>set</span> <span style=''>of</span> <span style=''>allowed</span> <span style=''>nonzero</span> <span style=''>patterns</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>solutions</span> <span style=''>of</span> <span style=''>such</span> <span style=''>problems</span> <span style=''>We</span> <span style=''>first</span> <span style=''>explore</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relationship</span> <span style=''>between</span> <span style=''>the</span> <span style=''>groups</span> <span style=''>defining</span> <span style=''>the</span> <span style=''>norm</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style=''>nonzero</span> <span style=''>patterns</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>providing</span> <span style=''>both</span> <span style=''>forward</span> <span style=''>and</span> <span style=''>backward</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>to</span> <span style=''>go</span> <span style=''>back</span> <span style=''>and</span> <span style=''>forth</span> <span style=''>from</span> <span style=''>groups</span> <span style=''>to</span> <span style=''>patterns</span> <span style=''>This</span> <span style=''>allows</span> <span style=''>the</span> <span style=''>design</span> <span style=''>of</span> <span style=''>norms</span> <span style=''>adapted</span> <span style=''>to</span> <span style=''>specific</span> <span style=''>prior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expressed</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Nearly</span> <span style=''>Optimal</span> <span style=''>Robust</span> <span style=''>Subspace</span> <span style=''>Tracking</span> <span style=''>and</span> <span style=''>Dynamic</span> <span style=''>Robust</span> <span style=''>PCA</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style=''>robust</span> <span style=''>subspace</span> <span style=''>tracking</span> <span style=''>(RST)</span> <span style=''>problem</span> <span style=''>and</span> <span style=''>obtain</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>first</span> <span style=''>provable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantees</span> <span style=''>for</span> <span style=''>it</span> <span style=''>The</span> <span style=''>goal</span> <span style=''>of</span> <span style=''>RST</span> <span style=''>is</span> <span style=''>to</span> <span style=''>track</span> <span style=''>data</span> <span style=''>that</span> <span style=''>lies</span> <span style=''>in</span> <span style=''>a</span> <span style=''>slowly</span> <span style=''>changing</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.41417910447761197);'>dimensional</span> <span style=''>subspace</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>subspaces</span> <span style='background-color:rgba(0, 255, 0, 0.4210526315789473);'>themselves</span> <span style=''>while</span> <span style=''>being</span> <span style=''>robust</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.39999999999999997);'>corruption</span> <span style=''>by</span> <span style=''>(often</span> <span style=''>large</span> <span style=''>magnitude)</span> <span style=''>sparse</span> <span style=''>outliers</span> <span style=''>It</span> <span style=''>can</span> <span style=''>be</span> <span style=''>simply</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpreted</span> <span style=''>as</span> <span style=''>a</span> <span style=''>dynamic</span> <span style=''>(time</span> <span style=''>varying)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extension</span> <span style=''>of</span> <span style=''>robust</span> <span style=''>PCA</span> <span style=''>with</span> <span style=''>the</span> <span style=''>minor</span> <span style='background-color:rgba(0, 255, 0, 0.4222222222222222);'>difference</span> <span style=''>that</span> <span style=''>RST</span> <span style=''>also</span> <span style=''>requires</span> <span style=''>an</span> <span style=''>online</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>(short</span> <span style=''>tracking</span> <span style=''>delay)</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>called</span> <span style=''>NORST</span> <span style=''>(nearly</span> <span style=''>optimal</span> <span style=''>RST)</span> <span style=''>and</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>it</span> <span style=''>solves</span> <span style=''>both</span> <span style=''>RST</span> <span style=''>and</span> <span style=''>dynamic</span> <span style=''>robust</span> <span style=''>PCA</span> <span style=''>under</span> <span style=''>weakened</span> <span style=''>versions</span> <span style=''>of</span> <span style=''>standard</span> <span style=''>RPCA</span> <span style='background-color:rgba(255, 0, 0, 0.37967914438502676);'>assumptions</span> <span style=''>slow</span> <span style=''>subspace</span> <span style=''>change</span> <span style=''>and</span> <span style=''>two</span> <span style=''>simple</span> <span style=''>extra</span> <span style='background-color:rgba(255, 0, 0, 0.37967914438502676);'>assumptions</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Compact</span> <span style=''>Multi</span> <span style=''>Class</span> <span style=''>Boosted</span> <span style=''>Trees</span> <br/><br/><span style=''>Gradient</span> <span style=''>boosted</span> <span style=''>decision</span> <span style=''>trees</span> <span style=''>are</span> <span style=''>a</span> <span style=''>popular</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>in</span> <span style=''>part</span> <span style=''>because</span> <span style=''>of</span> <span style=''>their</span> <span style=''>ability</span> <span style=''>to</span> <span style=''>give</span> <span style=''>good</span> <span style=''>accuracy</span> <span style=''>with</span> <span style=''>small</span> <span style=''>models</span> <span style=''>We</span> <span style=''>describe</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extensions</span> <span style=''>to</span> <span style=''>the</span> <span style=''>standard</span> <span style=''>tree</span> <span style=''>boosting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>designed</span> <span style=''>to</span> <span style=''>increase</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>advantage</span> <span style=''>The</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>improvement</span> <span style=''>extends</span> <span style=''>the</span> <span style=''>boosting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formalism</span> <span style=''>from</span> <span style=''>scalar</span> <span style=''>valued</span> <span style=''>trees</span> <span style=''>to</span> <span style=''>vector</span> <span style=''>valued</span> <span style=''>trees</span> <span style=''>This</span> <span style=''>allows</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style=''>trees</span> <span style=''>to</span> <span style=''>be</span> <span style=''>used</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multiclass</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style=''>rather</span> <span style=''>than</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>requiring</span> <span style=''>one</span> <span style=''>tree</span> <span style=''>per</span> <span style=''>class</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>drastically</span> <span style=''>reduces</span> <span style=''>the</span> <span style=''>model</span> <span style=''>size</span> <span style=''>required</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multiclass</span> <span style=''>problems</span> <span style=''>We</span> <span style=''>also</span> <span style=''>show</span> <span style=''>that</span> <span style=''>some</span> <span style=''>other</span> <span style=''>popular</span> <span style=''>vector</span> <span style=''>valued</span> <span style=''>gradient</span> <span style=''>boosted</span> <span style=''>trees</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>modifications</span> <span style=''>fit</span> <span style=''>into</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulation</span> <span style=''>and</span> <span style=''>can</span> <span style=''>be</span> <span style=''>easily</span> <span style=''>obtained</span> <span style=''>in</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implementation</span> <span style=''>The</span> <span style=''>second</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extension</span> <span style=''>layer</span> <span style=''>by</span> <span style=''>layer</span> <span style=''>boosting</span> <span style=''>takes</span> <span sty ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.1345875542691751)
# 	challenging (0.0987698986975398)
# 	architecture (0.08791606367583213)
# 	segmentation (0.07416787264833574)
# 	representation (0.1385672937771346)
# 	information (0.26049204052098407)
# 	different (0.27170767004341534)
# 	detection (0.13314037626628075)
# 	recognition (0.13784370477568741)
# 	convolutional (0.14254703328509408)
#
# Some Statistics words are:
# 	stochastic (0.12524557956777996)
# 	theoretical (0.14047151277013753)
# 	variables (0.14636542239685657)
# 	algorithm (0.37229862475442044)
# 	estimation (0.17485265225933203)
# 	statistical (0.15864440078585462)
# 	distribution (0.1900785854616896)
# 	inference (0.1969548133595285)
# 	dimensional (0.18614931237721022)
# 	regression (0.18172888015717092)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="3677c567-075d-4409-adf2-7a43efeba7ab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3677c567-075d-4409-adf2-7a43efeba7ab")) {                    Plotly.newPlot(                        "3677c567-075d-4409-adf2-7a43efeba7ab",                        [{"x":["combinations","representative","variation","demonstrate","considerably","constrained","interdependence","developed","capturing","estimates","represented","properties","recognition","appropriate","originally","resulting","experimentally","procedure","representation","accurately","generative","traditional","different","distribution","multimodal","highlighting","techniques","information","according","applications","interaction","referring","recognize","increasing","interfaces","systematic","literature","sequences","movements","development","characterized","psycholinguistic","discourse","conversation","organized","laborious","methodology","understand","compositional","disambiguation","compounds","evaluations","investigating","representations","disambiguate","effective","classification","considered","classifiers","measurement","increases","integrating","diversity","community","predictions","significantly","weighting","classifier","filtering","selecting","detrimental","technique","determine","identification","instances","algorithms","approaches","depression","misspecification","consistency","variables","predictors","application","propensity","penalized","treatment","asymptotic","regressions","investigated","conditional","selection","important","simulations","estimation","estimators","regression","dimension","dimensional","empirical","misspecified","polynomial","distributions","evaluated","estimated","dimensionality","framework","performance","component","significant","projections","frequently","projected","projection","extensive","outperforms","typically","principal","predictive","proposing","statistically","alternative","prediction","heuristic","particular","components","assumptions","widespread","straightforward","reduction","successful","competitive","experiments","minimizes","difference","supervised","examination","implement","strategies","baselines","describes","evaluation","embeddings","computation","candidate","embedding","similarity","performed","sentences","construct","isomorphic","possesses","representable","regularized","admissible","reproducing","targeting","functions","isometrically","continuous","construction","functionals","representer","integrable","correspond","interacting","postulated","explanatory","learnable","disentangle","disentangling","disentangles","experiment","variations","postulate","statistical","objective","controllable","discovered","potentially","independently","underlying","hypothesize","extrinsic","environment","specifically","fundamental","direction","relations","univariate","synthetic","observational","functional","efficient","practical","inferring","description","especially","algorithm","complexity","principle","introduce","independence","difficult","theoretic","kolmogorov","compression","reasonably","resources","constrain","expressions","considerations","unconstrained","annealing","programmable","advantage","experimental","potential","classical","establish","controlling","introducing","existence","disentangled","disentanglement","autoencoder","consistent","independent","discriminative","available","quantifying","autoencoders","predictable","behaviour","variational","parameter","interpretable","consequences","extension","enforcing","constructed","demonstrated","characteristics","processing","laplacian","essential","microscopic","blurriness","detection","comprised","dictionary","illumination","determines","presented","operators","eliminates","cryptograp ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	depression
# 	propensity
# 	isometrically
# 	disentangles
# 	hoeffding
# 	underscore
# 	differentiability
# 	invertibility
# 	certificate
# 	supernova
# 	timescales
# 	inclusions
# 	sinusoidal
# 	missforest
# 	suspected
# 	preconditioning
# 	therapies
# 	stimulation
# 	stimulated
# 	decomposability
# Some words which never appear in Statistics papers:
# 	referring
# 	psycholinguistic
# 	discourse
# 	disambiguation
# 	disambiguate
# 	illumination
# 	cryptography
# 	steganography
# 	encryption
# 	unauthorized
# 	imperceptibility
# 	transmitted
# 	entangled
# 	photographers
# 	radiometric
# 	grounding
# 	transmissions
# 	nonseparable
# 	ultrasound
# 	proficiency

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0979894048762353e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7983333333333333
